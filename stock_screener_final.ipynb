# %% [markdown]
# # Stock screener

# %% [markdown]
# This notebook introduces a new idea of screening for stocks based on calculating momentum. Basically,
# averages of close prices in sequential windows (in this case I choose windows of 90 days = 1 quarter) are compared against each other. Window 0 is the latest available time window. Window 1 is 90 days before
# window 0 and so on. If average close price of window 1 is larger than window 0 then momentum -1, otherwise momentum +1. Final sum of momentum is calculated. If momentum <0 then the stock is bear,  otherwise bull.
# My picking criteria in this case is to choose tech stocks with ex-dividend != 0, momentum of 90-day window over 5 years is negative, or momentum of 30-day window over 1 year period is positive, or momentum of 1-day window over 3 month period is positive.

# %%
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px
import numpy as np
import datetime as dt

# %%
# Download Nasdaq end of day data. This  data source categorizes0 stocks into industries and sectors
all = pd.read_csv("C:\\Dropbox\\nasdaq_screener_1640752808062.csv", header = 0)
all[['Sector','Industry']] = all[['Sector','Industry']].fillna('Unclassified')
all
# Out:
#      Symbol                                               Name Last Sale  \
# 0         A             Agilent Technologies Inc. Common Stock   $159.18
# 1        AA                    Alcoa Corporation Common Stock     $59.19
# 2       AAC  Ares Acquisition Corporation Class A Ordinary ...     $9.74
# 3      AACG   ATA Creativity Global American Depositary Shares     $1.17
# 4      AACI            Armada Acquisition Corp. I Common Stock     $9.80
# ...     ...                                                ...       ...
# 8282    ZWS      Zurn Water Solutions Corporation Common Stock    $36.66
# 8283     ZY                         Zymergen Inc. Common Stock     $7.10
# 8284   ZYME                       Zymeworks Inc. Common Shares    $15.76
# 8285   ZYNE          Zynerba Pharmaceuticals Inc. Common Stock     $3.05
# 8286   ZYXI                            Zynex Inc. Common Stock    $10.05
#
#       Net Change % Change    Market Cap        Country  IPO Year   Volume  \
# 0           0.44   0.277%  4.807249e+10  United States    1999.0   764279
# 1          -0.64   -1.07%  1.107464e+10            NaN    2016.0  6000817
# 2           0.00    0.00%  1.217500e+09            NaN    2021.0     8352
# 3          -0.01  -0.847%  3.671100e+07          China       NaN    26754
# 4           0.00    0.00%  2.029531e+08  United States    2021.0    15682
# ...          ...      ...           ...            ...       ...      ...
# 8282        0.19   0.521%  4.448673e+09  United States    2012.0   415326
# 8283       -0.06  -0.838%  7.270456e+08  United States    2021.0   636193
# 8284       -0.06  -0.379%  7.336905e+08         Canada    2017.0   299830
# 8285       -0.11  -3.481%  1.257135e+08  United States    2015.0   935491
# 8286       -0.43  -4.103%  3.663578e+08  United States       NaN   226575
#
#                 Sector                                           Industry
# 0        Capital Goods                                Electrical Products
# 1     Basic Industries                                 Metal Fabrications
# 2              Finance                                  Business Services
# 3        Miscellaneous                     Service to the Health Industry
# 4         Unclassified                                       Unclassified
# ...                ...                                                ...
# 8282  Public Utilities                                       Water Supply
# 8283  Basic Industries                             Industrial Specialties
# 8284      Unclassified                                       Unclassified
# 8285       Health Care         Biotechnology: Pharmaceutical Preparations
# 8286       Health Care  Biotechnology: Electromedical & Electrotherape...
#
# [8287 rows x 11 columns]

# %%
# Check to see which sectors are available
all['Sector'].unique()
# Out:
# array(['Capital Goods', 'Basic Industries', 'Finance', 'Miscellaneous',
#        'Unclassified', 'Health Care', 'Consumer Services',
#        'Transportation', 'Technology', 'Consumer Durables',
#        'Consumer Non-Durables', 'Energy', 'Public Utilities'],
#       dtype=object)

# %%
# Slice Technology sector
tech = all['Symbol'].loc[all['Sector'] == 'Technology']

# %%
# Load wiki data which contain historical time series data of all US stocks
wiki = pd.read_csv("C:\\Users\\daile\\Documents\\WIKI_PRICES_212b326a081eacca455e13140d7bb9db.csv", header = 0)

# %%
# Slice technology stocks in wiki data
wikitech = pd.DataFrame()
for i in tech:
    if i in wiki['ticker'].values:
        wikitech = wikitech.append(wiki[wiki['ticker'] == i])
wikitech
# Out:
#          ticker        date   open    high    low  close      volume  \
# 17894      AAOI  2013-09-26  10.00  10.090   9.37   9.96    946000.0
# 17895      AAOI  2013-09-27  10.44  10.440  10.00  10.10    253300.0
# 17896      AAOI  2013-09-30  10.00  10.180   9.71  10.00     84900.0
# 17897      AAOI  2013-10-01   9.95  10.024   9.92  10.00     74500.0
# 17898      AAOI  2013-10-02   9.99  10.000   9.89   9.97     94000.0
# ...         ...         ...    ...     ...    ...    ...         ...
# 15377357   ZNGA  2018-03-21   3.85   3.940   3.81   3.94  17590899.0
# 15377358   ZNGA  2018-03-22   3.88   3.940   3.80   3.81  14379224.0
# 15377359   ZNGA  2018-03-23   3.81   3.860   3.79   3.80   9850955.0
# 15377360   ZNGA  2018-03-26   3.85   3.860   3.78   3.85   9075940.0
# 15377361   ZNGA  2018-03-27   3.85   3.850   3.68   3.70  11026010.0
#
#           ex-dividend  split_ratio  adj_open  adj_high  adj_low  adj_close  \
# 17894             0.0          1.0     10.00    10.090     9.37       9.96
# 17895             0.0          1.0     10.44    10.440    10.00      10.10
# 17896             0.0          1.0     10.00    10.180     9.71      10.00
# 17897             0.0          1.0      9.95    10.024     9.92      10.00
# 17898             0.0          1.0      9.99    10.000     9.89       9.97
# ...               ...          ...       ...       ...      ...        ...
# 15377357          0.0          1.0      3.85     3.940     3.81       3.94
# 15377358          0.0          1.0      3.88     3.940     3.80       3.81
# 15377359          0.0          1.0      3.81     3.860     3.79       3.80
# 15377360          0.0          1.0      3.85     3.860     3.78       3.85
# 15377361          0.0          1.0      3.85     3.850     3.68       3.70
#
#           adj_volume
# 17894       946000.0
# 17895       253300.0
# 17896        84900.0
# 17897        74500.0
# 17898        94000.0
# ...              ...
# 15377357  17590899.0
# 15377358  14379224.0
# 15377359   9850955.0
# 15377360   9075940.0
# 15377361  11026010.0
#
# [1225088 rows x 14 columns]

# %%
# Function to get data of a particular ticker provided by wiki
def getdf(wikidf,ticker):
    df = wikidf[wikidf['ticker']== ticker]
    df = df.set_index('date')
    df.index = df.index.astype('datetime64[ns]')
    print(f'Data for {ticker}')
    return df

# %%
''' Function to calculate rolling mean. This function takes time window and period as arguments and
return dataframe with calculated means and momentum '''
def rollingmean(sdf,window, period):
    sdf = sdf[['open','close','volume','ex-dividend','split_ratio','adj_open','adj_close','adj_volume']]
    sdfmean = []
    date = []
    momentum = []
    for i in range(2,period):
        max0 = sdf[pd.to_datetime(sdf.index)>(pd.to_datetime(sdf.index.max()+dt.timedelta(days = -window)))]
        max1 = sdf[pd.to_datetime(sdf.index)>(pd.to_datetime(sdf.index.max()+dt.timedelta(days = -window*(i-1))))].index.max()
        max2 = sdf[pd.to_datetime(sdf.index)>(pd.to_datetime(max1+dt.timedelta(days = -window*i)))]
        sdfmean.append(max0.mean())
        sdfmean.append(max2.mean())
        if (max2['close'].mean() < max0['close'].mean()):
            momentum.append(1)
        else:
            momentum.append(-1)
        date.append(max1)
        date.append(max2.index[0])
    df = pd.DataFrame(sdfmean)
    df['date'] = date
    df['date'] = df['date'].astype('datetime64[ns]')
    df = df.set_index('date')
    df = df.sort_index()
    df = df.drop_duplicates()
    df = df.round(4)
    return df, momentum

# %%
'''Screening for tech stocks that have ex-dividend != 0, momentum of 90-day window over 5 years
 is negative, while momentum of 30-day window over 1 year period is positive, momentum of 1-day window
 over 3 month period is positive'''
techlist = []
for i in tech:
    df = getdf(wikitech,i)
    if df['volume'].any()!=0:
        mean, momentum90 = rollingmean(df, 90, 20)
        print(sum(momentum90))
        if sum(momentum90) <0 and sum(mean['ex-dividend']) > 0:
            techlist.append(i)
    else:
        pass
# Out:
# Data for AAOI
# -2
# Data for AAPL
# 14
# Data for ABM
# -2
# Data for ACEV
# Data for ACEVU
# Data for ACEVW
# Data for ACIW
# 12
# Data for ACLS
# 14
# Data for ACMR
# Data for ACN
# 18
# Data for ACVA
# Data for ACY
# Data for ADBE
# 18
# Data for ADI
# 18
# Data for ADSK
# 18
# Data for ADTH
# Data for ADV
# Data for ADVWW
# Data for AER
# Data for AEYE
# Data for AFRM
# Data for AGIL
# Data for AGILW
# Data for AGMH
# Data for AGYS
# 16
# Data for AI
# -18
# Data for AIP
# Data for AIRG
# Data for AL
# 18
# Data for ALF
# Data for ALFIW
# Data for ALGM
# Data for ALIT
# Data for ALKT
# Data for ALOT
# Data for ALRM
# Data for ALTG
# Data for ALTR
# -18
# Data for AMBA
# -16
# Data for AMD
# 12
# Data for AMKR
# 10
# Data for AMPL
# Data for AMST
# Data for AMSWA
# 18
# Data for AMWL
# Data for ANET
# Data for ANGI
# 18
# Data for ANSS
# 18
# Data for ANTE
# Data for AOSL
# 2
# Data for API
# Data for APP
# -18
# Data for APPF
# Data for APPN
# Data for APPS
# Data for ARNC
# 18
# Data for ARRY
# 18
# Data for ARW
# 18
# Data for ASAN
# Data for ASGN
# 18
# Data for ASML
# Data for ASUR
# Data for ASX
# Data for ASYS
# Data for ATEN
# -18
# Data for ATHM
# Data for ATKR
# Data for ATOM
# Data for ATVI
# 18
# Data for AUGX
# Data for AUID
# Data for AUR
# Data for AUROW
# Data for AUUD
# Data for AUUDW
# Data for AVCT
# Data for AVCTW
# Data for AVDX
# Data for AVGO
# 14
# Data for AVGOP
# Data for AVID
# -12
# Data for AVLR
# Data for AVPT
# Data for AVPTW
# Data for AVT
# 4
# Data for AVYA
# Data for AWRE
# Data for AXTI
# Data for AYX
# Data for AZPN
# 18
# Data for AZTA
# Data for BAND
# Data for BASE
# Data for BBAI
# Data for BBSI
# 18
# Data for BCOV
# -18
# Data for BDR
# Data for BEAT
# 18
# Data for BEATW
# Data for BEEM
# Data for BEEMW
# Data for BGSF
# Data for BHE
# 8
# Data for BIDU
# 18
# Data for BIGC
# Data for BILI
# Data for BILL
# Data for BKI
# Data for BKKT
# Data for BKTI
# Data for BL
# Data for BLBX
# Data for BLCT
# Data for BLIN
# Data for BLKB
# 18
# Data for BLND
# Data for BLZE
# Data for BMBL
# Data for BMTX
# Data for BNFT
# -18
# Data for BOMN
# Data for BOSC
# Data for BOX
# Data for BRDS
# Data for BRZE
# Data for BSQR
# Data for BSY
# Data for BTCM
# Data for BTRS
# Data for BTRSW
# Data for BW
# Data for CACI
# 18
# Data for CALX
# -10
# Data for CAN
# Data for CANG
# Data for CASA
# Data for CCCS
# Data for CCMP
# 18
# Data for CCO
# -8
# Data for CCRN
# -10
# Data for CCSI
# Data for CDAY
# Data for CDK
# Data for CDLX
# Data for CDNS
# 16
# Data for CDW
# Data for CETX
# Data for CETXP
# Data for CETXW
# Data for CEVA
# 10
# Data for CFLT
# Data for CGNT
# Data for CHKP
# 10
# Data for CIH
# Data for CLIR
# Data for CLPS
# Data for CLRO
# Data for CLSK
# Data for CMAX
# Data for CMAXW
# Data for CMBM
# Data for CMCM
# Data for CMTL
# 12
# Data for CNDT
# Data for CNET
# Data for CNVY
# Data for CNXC
# Data for CNXN
# Data for COIN
# Data for COMM
# Data for COMP
# Data for COUP
# 18
# Data for CPSI
# -8
# Data for CREX
# Data for CREXW
# Data for CRM
# 18
# Data for CRNC
# Data for CRNT
# Data for CRSR
# Data for CRTO
# Data for CRUS
# -2
# Data for CRWD
# Data for CSCO
# 18
# Data for CSGS
# 18
# Data for CSPI
# Data for CTEK
# Data for CTG
# 8
# Data for CTK
# Data for CTLP
# Data for CTOS
# Data for CTSH
# 18
# Data for CTV
# Data for CTXS
# 18
# Data for CUEN
# Data for CUENW
# Data for CVLT
# 6
# Data for CVT
# 16
# Data for CVV
# Data for CWAN
# Data for CXM
# Data for CYBR
# Data for CYN
# 14
# Data for CYRN
# Data for CYXT
# Data for CYXTW
# Data for DATS
# Data for DATSW
# Data for DAVA
# Data for DBD
# -18
# Data for DBX
# Data for DCT
# 14
# Data for DDD
# -16
# Data for DDI
# Data for DDOG
# Data for DELL
# 18
# Data for DGII
# -2
# Data for DH
# Data for DHX
# -18
# Data for DIOD
# 16
# Data for DLB
# 18
# Data for DLX
# 18
# Data for DM
# Data for DMRC
# -8
# Data for DMS
# Data for DNB
# 14
# Data for DOCN
# Data for DOCS
# Data for DOCU
# Data for DOMO
# Data for DOX
# 18
# Data for DOYU
# Data for DQ
# Data for DSP
# Data for DT
# Data for DTSS
# Data for DTST
# Data for DTSTW
# Data for DUO
# Data for DUOL
# Data for DUOT
# Data for DV
# 18
# Data for DXC
# 18
# Data for EA
# 18
# Data for EB
# Data for EBIX
# 18
# Data for EBON
# Data for ECOM
# Data for EEFT
# 12
# Data for EEX
# Data for EFX
# 2
# Data for EGAN
# 18
# Data for EGHT
# 18
# Data for ELTK
# Data for EMBK
# Data for EMBKW
# Data for EMKR
# Data for ENFN
# Data for ENTG
# 18
# Data for ENV
# 18
# Data for EOSE
# Data for EOSEW
# Data for EPAM
# 18
# Data for EPAY
# 18
# Data for ERIC
# Data for ERII
# 2
# Data for ESMT
# Data for ESSC
# Data for ESTC
# Data for ETWO
# Data for EVBG
# Data for EVCM
# Data for EVER
# 18
# Data for EVOL
# Data for EVOP
# Data for EVTC
# -16
# Data for EXFY
# Data for EXLS
# 16
# Data for EXTN
# Data for EZFL
# Data for FB
# 18
# Data for FDS
# 18
# Data for FFIV
# 18
# Data for FICO
# 18
# Data for FISV
# 18
# Data for FIVN
# 18
# Data for FLEX
# Data for FLT
# 18
# Data for FLYW
# Data for FORA
# Data for FORG
# Data for FORM
# 12
# Data for FORTY
# Data for FOUR
# Data for FROG
# Data for FRSH
# -10
# Data for FRSX
# Data for FSLR
# 14
# Data for FSLY
# Data for FSS
# 16
# Data for FTAI
# Data for FTCI
# Data for FTFT
# Data for GAN
# Data for GB
# -18
# Data for GBOX
# Data for GDDY
# Data for GDOT
# 18
# Data for GDRX
# Data for GDS
# Data for GDYN
# Data for GIC
# Data for GIGM
# Data for GILT
# Data for GLBE
# Data for GLG
# Data for GOOG
# 18
# Data for GOOGL
# 18
# Data for GRPN
# 8
# Data for GSIT
# 18
# Data for GSKY
# Data for GSMG
# Data for GSMGW
# Data for GTEC
# Data for GTLB
# Data for GTLS
# 18
# Data for GTYH
# Data for GVP
# Data for GWRE
# 18
# Data for HAYW
# Data for HCKT
# 18
# Data for HCP
# -18
# Data for HCTI
# Data for HEES
# 18
# Data for HHR
# Data for HHS
# 18
# Data for HIMX
# Data for HLIT
# -18
# Data for HLTH
# Data for HOOD
# Data for HPQ
# 10
# Data for HQI
# Data for HRI
# Data for HSII
# 18
# Data for HSON
# Data for HUBS
# Data for IAS
# Data for IBEX
# Data for IBM
# 10
# Data for ICHR
# Data for ICLK
# Data for IDEX
# Data for IDN
# Data for IGC
# Data for III
# 18
# Data for IIIV
# Data for IMMR
# 18
# Data for IMOS
# Data for IMXI
# Data for INDI
# Data for INDIW
# Data for INFA
# 18
# Data for INFO
# 18
# Data for INFY
# Data for INOD
# Data for INPX
# Data for INS
# Data for INST
# Data for INSW
# Data for INTA
# Data for INTC
# 18
# Data for INTT
# Data for INTU
# 18
# Data for INUV
# Data for INVE
# Data for IOT
# Data for IPDN
# Data for IPG
# 4
# Data for IPGP
# 18
# Data for IQ
# Data for IRNT
# Data for ISDR
# Data for ISIG
# Data for ISUN
# Data for ITRN
# Data for IZEA
# Data for JAMF
# Data for JBL
# 10
# Data for JG
# Data for JKHY
# 18
# Data for JKS
# Data for JNPR
# 6
# Data for JOB
# Data for JOBS
# Data for JT
# Data for KAI
# 16
# Data for KARO
# Data for KBNT
# Data for KBNTW
# Data for KC
# Data for KD
# Data for KELYA
# 18
# Data for KELYB
# Data for KFRC
# 18
# Data for KFY
# 18
# Data for KLIC
# Data for KLR
# Data for KLTR
# Data for KNBE
# Data for KPLT
# Data for KPLTW
# Data for KTCC
# Data for KVHI
# 6
# Data for LASR
# Data for LAW
# Data for LAZR
# Data for LDOS
# 18
# Data for LEDS
# Data for LFUS
# 18
# Data for LITE
# Data for LIZI
# Data for LOGI
# Data for LPSN
# 18
# Data for LRCX
# 18
# Data for LSCC
# -6
# Data for LTCH
# Data for LTCHW
# Data for LVOX
# Data for LVOXW
# Data for LYFT
# Data for LYLT
# Data for LZ
# Data for MAN
# 16
# Data for MANH
# -10
# Data for MANT
# 18
# Data for MAPS
# Data for MAPSW
# Data for MCFE
# Data for MCHP
# 18
# Data for MCO
# 18
# Data for MDB
# Data for MDRX
# 18
# Data for MFC
# Data for MFGP
# Data for MFH
# Data for MGIC
# Data for MGNI
# Data for MGRC
# 18
# Data for MICT
# Data for MIGI
# Data for MIME
# Data for MIR
# Data for MITK
# 10
# Data for MIXT
# Data for MKFG
# Data for MKTW
# Data for MKTWW
# Data for ML
# Data for MMAT
# Data for MNDO
# Data for MNDT
# Data for MNTV
# Data for MOBQ
# Data for MOBQW
# Data for MODN
# 18
# Data for MOMO
# Data for MORN
# 18
# Data for MPWR
# 18
# Data for MQ
# Data for MRAM
# Data for MRIN
# 16
# Data for MRVL
# 18
# Data for MSCI
# 18
# Data for MSFT
# 18
# Data for MSI
# 18
# Data for MSP
# Data for MSTR
# -16
# Data for MTC
# Data for MTLS
# Data for MTSI
# -18
# Data for MTTR
# Data for MTTRW
# Data for MU
# 18
# Data for MX
# Data for MXL
# 14
# Data for MYPS
# Data for MYPSW
# Data for MYSZ
# Data for NABL
# Data for NATI
# 18
# Data for NCMI
# -16
# Data for NCNO
# Data for NCTY
# Data for NET
# Data for NEWR
# Data for NICE
# Data for NLOK
# Data for NNDM
# Data for NOK
# Data for NOW
# 18
# Data for NPTN
# -16
# Data for NRDS
# Data for NRDY
# Data for NSIT
# 4
# Data for NSP
# -6
# Data for NTAP
# 18
# Data for NTCT
# -18
# Data for NTNX
# Data for NTWK
# Data for NUAN
# 18
# Data for NVDA
# 18
# Data for NVEC
# 16
# Data for NVTS
# Data for NVTSW
# Data for NXPI
# Data for NXTP
# Data for OBLG
# Data for OCFT
# Data for OIIM
# Data for OKTA
# Data for OLB
# Data for OLED
# 16
# Data for OLO
# Data for OMC
# -14
# Data for OMQS
# Data for ON
# Data for ONEM
# Data for ONTF
# Data for ONTO
# Data for OPFI
# Data for OPRA
# Data for ORCL
# 18
# Data for OSPN
# Data for OSS
# Data for OTRK
# Data for OTRKP
# Data for PAGS
# Data for PALT
# Data for PANW
# 18
# Data for PAR
# Data for PATH
# Data for PAY
# -18
# Data for PAYA
# Data for PAYC
# 18
# Data for PAYO
# Data for PAYOW
# Data for PAYS
# Data for PBTS
# Data for PCOR
# Data for PCTI
# 18
# Data for PCTY
# 18
# Data for PCYG
# -18
# Data for PD
# Data for PDFS
# -18
# Data for PEAR
# Data for PEARW
# Data for PEGA
# 12
# Data for PERI
# -18
# Data for PFDRU
# Data for PFDRW
# Data for PHUN
# Data for PHUNW
# Data for PING
# Data for PIXY
# Data for PLAB
# -18
# Data for PLAN
# Data for PLTK
# Data for PLTR
# Data for PLUS
# -18
# Data for PLXS
# 18
# Data for POWI
# 12
# Data for PRAA
# 2
# Data for PRCH
# Data for PRFT
# 18
# Data for PRG
# Data for PRGS
# 18
# Data for PRO
# 18
# Data for PRTH
# Data for PRVA
# Data for PSTG
# Data for PT
# Data for PTC
# Data for PUBM
# Data for PWSC
# Data for PXLW
# Data for PYCR
# Data for QCOM
# 18
# Data for QD
# Data for QLYS
# 18
# Data for QMCO
# Data for QNST
# 18
# Data for QTT
# Data for QTWO
# 18
# Data for QUBT
# Data for QUIK
# 10
# Data for QUMU
# Data for QUOT
# Data for RAAS
# Data for RAMP
# Data for RBBN
# Data for RBCN
# 14
# Data for RBLX
# Data for RCAT
# Data for RCII
# -18
# Data for RDCM
# Data for RDVT
# Data for RDWR
# Data for REKR
# Data for RELL
# 16
# Data for RELY
# Data for RENN
# Data for RESN
# Data for RHI
# 18
# Data for RIOT
# Data for RMBS
# 14
# Data for RMNI
# Data for RNG
# 18
# Data for RNWK
# -18
# Data for ROL
# 18
# Data for RPAY
# Data for RPD
# Data for RSSS
# Data for RXT
# Data for S
# -18
# Data for SABR
# Data for SABRP
# Data for SAIC
# 18
# Data for SAIL
# Data for SANM
# -4
# Data for SAP
# Data for SATS
# 18
# Data for SCKT
# Data for SCPL
# Data for SCSC
# -18
# Data for SCWX
# Data for SDGR
# Data for SE
# -18
# Data for SEAC
# -2
# Data for SEDG
# Data for SEMR
# Data for SFET
# Data for SFUN
# Data for SGFY
# Data for SGH
# Data for SGLB
# Data for SGLBW
# Data for SGMA
# Data for SHCR
# Data for SHCRW
# Data for SHLS
# Data for SILC
# Data for SIMO
# Data for SITM
# Data for SJ
# Data for SKLZ
# Data for SKYT
# Data for SLAB
# 18
# Data for SLF
# Data for SLP
# Data for SMAR
# Data for SMCI
# -18
# Data for SMFR
# Data for SMFRW
# Data for SMRT
# -18
# Data for SMSI
# Data for SMTC
# 12
# Data for SNAP
# Data for SNCE
# Data for SNCR
# -18
# Data for SNOW
# 18
# Data for SNPS
# 18
# Data for SNX
# 16
# Data for SOHU
# Data for SOL
# Data for SOPA
# Data for SPCB
# Data for SPGI
# 18
# Data for SPI
# Data for SPLK
# 18
# Data for SPNS
# -12
# Data for SPOK
# Data for SPSC
# -14
# Data for SPT
# Data for SPWR
# -18
# Data for SQ
# Data for SQNS
# Data for SQSP
# Data for SRAX
# Data for SREV
# -12
# Data for SSNC
# 14
# Data for SSNT
# Data for SSTI
# Data for SSYS
# -18
# Data for STAF
# Data for STEM
# Data for STER
# Data for STGW
# Data for STM
# Data for STNE
# Data for STRM
# Data for STRN
# Data for STRNW
# Data for STX
# 18
# Data for SUMO
# Data for SUNW
# Data for SURG
# Data for SURGW
# Data for SWCH
# Data for SWI
# 18
# Data for SWKS
# 14
# Data for SY
# Data for SYNA
# -14
# Data for TACT
# Data for TAIT
# Data for TAOP
# Data for TASK
# Data for TBI
# 18
# Data for TCX
# Data for TDC
# 16
# Data for TEAM
# Data for TEL
# 18
# Data for TENB
# Data for TGH
# 12
# Data for TLS
# Data for TNET
# 18
# Data for TOST
# Data for TPIC
# Data for TRIT
# Data for TRITW
# Data for TRKA
# Data for TRKAW
# Data for TRNS
# Data for TRS
# 14
# Data for TRT
# Data for TRTN
# Data for TRU
# Data for TRVG
# Data for TSEM
# Data for TSM
# Data for TSQ
# Data for TSRI
# Data for TTD
# Data for TTEC
# 12
# Data for TTMI
# 18
# Data for TTWO
# 18
# Data for TUFN
# Data for TUYA
# Data for TWKS
# Data for TWTR
# 14
# Data for TXN
# 18
# Data for TYL
# 18
# Data for TZOO
# -18
# Data for U
# Data for UBER
# Data for UCTT
# 12
# Data for UEPS
# Data for UI
# Data for UIS
# -14
# Data for ULBI
# Data for UMC
# Data for UPH
# Data for UPLD
# Data for URI
# 18
# Data for USER
# Data for USIO
# Data for UTRS
# Data for VALU
# Data for VCSA
# Data for VECO
# -18
# Data for VENAR
# Data for VERB
# Data for VERBW
# Data for VERI
# Data for VERX
# Data for VIAO
# Data for VIAV
# Data for VMEO
# Data for VMW
# 18
# Data for VNET
# Data for VOLT
# Data for VRAR
# Data for VRNS
# 18
# Data for VRNT
# -4
# Data for VRSN
# 18
# Data for VSAT
# 18
# Data for WAVD
# Data for WB
# Data for WDAY
# 18
# Data for WDC
# 18
# Data for WEAV
# Data for WEX
# 18
# Data for WFCF
# Data for WIMI
# Data for WISA
# Data for WIT
# Data for WIX
# 18
# Data for WK
# Data for WKEY
# Data for WOLF
# Data for WPP
# 4
# Data for WSC
# Data for WSTG
# Data for WTRH
# Data for WYY
# Data for XELA
# Data for XLNX
# 18
# Data for XM
# Data for XMTR
# Data for XNET
# Data for XPER
# Data for XRX
# 16
# Data for YALA
# Data for YELP
# 12
# Data for YEXT
# Data for YNDX
# Data for YOU
# Data for YY
# Data for ZBRA
# 18
# Data for ZD
# Data for ZDGE
# Data for ZEN
# 18
# Data for ZEPP
# Data for ZETA
# Data for ZI
# Data for ZIP
# Data for ZM
# Data for ZNGA
# 14
# Data for ZS
# Data for ZUO

# %%
#List of tickers that satisfy conditions
techlist
# Out:
# ['ABM',
#  'AI',
#  'ALTR',
#  'CCO',
#  'CPSI',
#  'DBD',
#  'DMRC',
#  'EVTC',
#  'HCP',
#  'NCMI',
#  'NSP',
#  'OMC',
#  'RCII',
#  'SE',
#  'SMRT',
#  'SPNS']

# %%
# Check for dividend and plot the whole data for verification
for i in techlist:
    df = getdf(wikitech,i)
    for j in df['ex-dividend']:
        if j !=0:
            print(f'expected dividend of {i} is {j}')
    fig = go.Figure()
    fig.add_trace(go.Scatter(x=df.index,y=df['close'], name = 'close'))
    fig.add_trace(go.Scatter(x=df.index,y = df['adj_close'], name = 'adjusted close'))
    fig.update_layout(title = i, template = 'plotly_dark')
    fig.show()
# Out:
# "for i in techlist:\n    df = getdf(wikitech,i)\n    for j in df['ex-dividend']:\n        if j !=0:\n            print(f'expected dividend of {i} is {j}')\n    fig = go.Figure()\n    fig.add_trace(go.Scatter(x=df.index,y=df['close'], name = 'close'))\n    fig.add_trace(go.Scatter(x=df.index,y = df['adj_close'], name = 'adjusted close'))\n    fig.update_layout(title = i, template = 'plotly_dark')\n    fig.show()"

# %%
techlist2 = []
for i in tech:
    df = getdf(wikitech,i)
    if df['volume'].any()!=0:
        mean, momentum30 = rollingmean(df, 30, 12)
        print(sum(momentum30))
        if sum(momentum30) > 0 and sum(mean['ex-dividend']) > 0:
            techlist2.append(i)
    else:
        pass
# Out:
# Data for AAOI
# -10
# Data for AAPL
# 10
# Data for ABM
# -10
# Data for ACEV
# Data for ACEVU
# Data for ACEVW
# Data for ACIW
# 10
# Data for ACLS
# -6
# Data for ACMR
# Data for ACN
# 10
# Data for ACVA
# Data for ACY
# Data for ADBE
# 10
# Data for ADI
# 10
# Data for ADSK
# 10
# Data for ADTH
# Data for ADV
# Data for ADVWW
# Data for AER
# Data for AEYE
# Data for AFRM
# Data for AGIL
# Data for AGILW
# Data for AGMH
# Data for AGYS
# -4
# Data for AI
# -6
# Data for AIP
# Data for AIRG
# Data for AL
# -4
# Data for ALF
# Data for ALFIW
# Data for ALGM
# Data for ALIT
# Data for ALKT
# Data for ALOT
# Data for ALRM
# Data for ALTG
# Data for ALTR
# -10
# Data for AMBA
# -8
# Data for AMD
# -6
# Data for AMKR
# 10
# Data for AMPL
# Data for AMST
# Data for AMSWA
# 10
# Data for AMWL
# Data for ANET
# Data for ANGI
# 10
# Data for ANSS
# 10
# Data for ANTE
# Data for AOSL
# -8
# Data for API
# Data for APP
# -10
# Data for APPF
# Data for APPN
# Data for APPS
# Data for ARNC
# -10
# Data for ARRY
# 10
# Data for ARW
# -6
# Data for ASAN
# Data for ASGN
# 10
# Data for ASML
# Data for ASUR
# Data for ASX
# Data for ASYS
# Data for ATEN
# -8
# Data for ATHM
# Data for ATKR
# Data for ATOM
# Data for ATVI
# 10
# Data for AUGX
# Data for AUID
# Data for AUR
# Data for AUROW
# Data for AUUD
# Data for AUUDW
# Data for AVCT
# Data for AVCTW
# Data for AVDX
# Data for AVGO
# -6
# Data for AVGOP
# Data for AVID
# -10
# Data for AVLR
# Data for AVPT
# Data for AVPTW
# Data for AVT
# 10
# Data for AVYA
# Data for AWRE
# Data for AXTI
# Data for AYX
# Data for AZPN
# 10
# Data for AZTA
# Data for BAND
# Data for BASE
# Data for BBAI
# Data for BBSI
# 10
# Data for BCOV
# 2
# Data for BDR
# Data for BEAT
# 10
# Data for BEATW
# Data for BEEM
# Data for BEEMW
# Data for BGSF
# Data for BHE
# 0
# Data for BIDU
# 10
# Data for BIGC
# Data for BILI
# Data for BILL
# Data for BKI
# Data for BKKT
# Data for BKTI
# Data for BL
# Data for BLBX
# Data for BLCT
# Data for BLIN
# Data for BLKB
# 10
# Data for BLND
# Data for BLZE
# Data for BMBL
# Data for BMTX
# Data for BNFT
# -8
# Data for BOMN
# Data for BOSC
# Data for BOX
# Data for BRDS
# Data for BRZE
# Data for BSQR
# Data for BSY
# Data for BTCM
# Data for BTRS
# Data for BTRSW
# Data for BW
# Data for CACI
# 10
# Data for CALX
# 10
# Data for CAN
# Data for CANG
# Data for CASA
# Data for CCCS
# Data for CCMP
# 10
# Data for CCO
# 10
# Data for CCRN
# -10
# Data for CCSI
# Data for CDAY
# Data for CDK
# Data for CDLX
# Data for CDNS
# -10
# Data for CDW
# Data for CETX
# Data for CETXP
# Data for CETXW
# Data for CEVA
# -10
# Data for CFLT
# Data for CGNT
# Data for CHKP
# -4
# Data for CIH
# Data for CLIR
# Data for CLPS
# Data for CLRO
# Data for CLSK
# Data for CMAX
# Data for CMAXW
# Data for CMBM
# Data for CMCM
# Data for CMTL
# 10
# Data for CNDT
# Data for CNET
# Data for CNVY
# Data for CNXC
# Data for CNXN
# Data for COIN
# Data for COMM
# Data for COMP
# Data for COUP
# 10
# Data for CPSI
# -4
# Data for CREX
# Data for CREXW
# Data for CRM
# 10
# Data for CRNC
# Data for CRNT
# Data for CRSR
# Data for CRTO
# Data for CRUS
# -10
# Data for CRWD
# Data for CSCO
# 10
# Data for CSGS
# 10
# Data for CSPI
# Data for CTEK
# Data for CTG
# 10
# Data for CTK
# Data for CTLP
# Data for CTOS
# Data for CTSH
# 10
# Data for CTV
# Data for CTXS
# 10
# Data for CUEN
# Data for CUENW
# Data for CVLT
# 0
# Data for CVT
# 4
# Data for CVV
# Data for CWAN
# Data for CXM
# Data for CYBR
# Data for CYN
# -2
# Data for CYRN
# Data for CYXT
# Data for CYXTW
# Data for DATS
# Data for DATSW
# Data for DAVA
# Data for DBD
# -8
# Data for DBX
# Data for DCT
# -8
# Data for DDD
# 4
# Data for DDI
# Data for DDOG
# Data for DELL
# 6
# Data for DGII
# 10
# Data for DH
# Data for DHX
# -10
# Data for DIOD
# 10
# Data for DLB
# 10
# Data for DLX
# 6
# Data for DM
# Data for DMRC
# -10
# Data for DMS
# Data for DNB
# -8
# Data for DOCN
# Data for DOCS
# Data for DOCU
# Data for DOMO
# Data for DOX
# 10
# Data for DOYU
# Data for DQ
# Data for DSP
# Data for DT
# Data for DTSS
# Data for DTST
# Data for DTSTW
# Data for DUO
# Data for DUOL
# Data for DUOT
# Data for DV
# 10
# Data for DXC
# 10
# Data for EA
# 10
# Data for EB
# Data for EBIX
# 4
# Data for EBON
# Data for ECOM
# Data for EEFT
# -8
# Data for EEX
# Data for EFX
# 2
# Data for EGAN
# 10
# Data for EGHT
# 10
# Data for ELTK
# Data for EMBK
# Data for EMBKW
# Data for EMKR
# Data for ENFN
# Data for ENTG
# 10
# Data for ENV
# 10
# Data for EOSE
# Data for EOSEW
# Data for EPAM
# 10
# Data for EPAY
# 10
# Data for ERIC
# Data for ERII
# -8
# Data for ESMT
# Data for ESSC
# Data for ESTC
# Data for ETWO
# Data for EVBG
# Data for EVCM
# Data for EVER
# 2
# Data for EVOL
# Data for EVOP
# Data for EVTC
# 10
# Data for EXFY
# Data for EXLS
# -8
# Data for EXTN
# Data for EZFL
# Data for FB
# -4
# Data for FDS
# 10
# Data for FFIV
# 10
# Data for FICO
# 10
# Data for FISV
# -10
# Data for FIVN
# 10
# Data for FLEX
# Data for FLT
# 10
# Data for FLYW
# Data for FORA
# Data for FORG
# Data for FORM
# -8
# Data for FORTY
# Data for FOUR
# Data for FROG
# Data for FRSH
# -6
# Data for FRSX
# Data for FSLR
# -8
# Data for FSLY
# Data for FSS
# 10
# Data for FTAI
# Data for FTCI
# Data for FTFT
# Data for GAN
# Data for GB
# -10
# Data for GBOX
# Data for GDDY
# Data for GDOT
# 10
# Data for GDRX
# Data for GDS
# Data for GDYN
# Data for GIC
# Data for GIGM
# Data for GILT
# Data for GLBE
# Data for GLG
# Data for GOOG
# 8
# Data for GOOGL
# 8
# Data for GRPN
# -8
# Data for GSIT
# 10
# Data for GSKY
# Data for GSMG
# Data for GSMGW
# Data for GTEC
# Data for GTLB
# Data for GTLS
# 10
# Data for GTYH
# Data for GVP
# Data for GWRE
# 10
# Data for HAYW
# Data for HCKT
# 10
# Data for HCP
# -10
# Data for HCTI
# Data for HEES
# 10
# Data for HHR
# Data for HHS
# 10
# Data for HIMX
# Data for HLIT
# -4
# Data for HLTH
# Data for HOOD
# Data for HPQ
# 10
# Data for HQI
# Data for HRI
# Data for HSII
# 10
# Data for HSON
# Data for HUBS
# Data for IAS
# Data for IBEX
# Data for IBM
# 6
# Data for ICHR
# Data for ICLK
# Data for IDEX
# Data for IDN
# Data for IGC
# Data for III
# 8
# Data for IIIV
# Data for IMMR
# 10
# Data for IMOS
# Data for IMXI
# Data for INDI
# Data for INDIW
# Data for INFA
# 10
# Data for INFO
# 10
# Data for INFY
# Data for INOD
# Data for INPX
# Data for INS
# Data for INST
# Data for INSW
# Data for INTA
# Data for INTC
# 10
# Data for INTT
# Data for INTU
# 10
# Data for INUV
# Data for INVE
# Data for IOT
# Data for IPDN
# Data for IPG
# 10
# Data for IPGP
# 8
# Data for IQ
# Data for IRNT
# Data for ISDR
# Data for ISIG
# Data for ISUN
# Data for ITRN
# Data for IZEA
# Data for JAMF
# Data for JBL
# 4
# Data for JG
# Data for JKHY
# 10
# Data for JKS
# Data for JNPR
# -10
# Data for JOB
# Data for JOBS
# Data for JT
# Data for KAI
# 6
# Data for KARO
# Data for KBNT
# Data for KBNTW
# Data for KC
# Data for KD
# Data for KELYA
# 10
# Data for KELYB
# Data for KFRC
# 10
# Data for KFY
# 10
# Data for KLIC
# Data for KLR
# Data for KLTR
# Data for KNBE
# Data for KPLT
# Data for KPLTW
# Data for KTCC
# Data for KVHI
# -10
# Data for LASR
# Data for LAW
# Data for LAZR
# Data for LDOS
# 10
# Data for LEDS
# Data for LFUS
# 10
# Data for LITE
# Data for LIZI
# Data for LOGI
# Data for LPSN
# 10
# Data for LRCX
# 10
# Data for LSCC
# 8
# Data for LTCH
# Data for LTCHW
# Data for LVOX
# Data for LVOXW
# Data for LYFT
# Data for LYLT
# Data for LZ
# Data for MAN
# -6
# Data for MANH
# -10
# Data for MANT
# 10
# Data for MAPS
# Data for MAPSW
# Data for MCFE
# Data for MCHP
# 10
# Data for MCO
# 10
# Data for MDB
# Data for MDRX
# -8
# Data for MFC
# Data for MFGP
# Data for MFH
# Data for MGIC
# Data for MGNI
# Data for MGRC
# 10
# Data for MICT
# Data for MIGI
# Data for MIME
# Data for MIR
# Data for MITK
# -8
# Data for MIXT
# Data for MKFG
# Data for MKTW
# Data for MKTWW
# Data for ML
# Data for MMAT
# Data for MNDO
# Data for MNDT
# Data for MNTV
# Data for MOBQ
# Data for MOBQW
# Data for MODN
# 10
# Data for MOMO
# Data for MORN
# 8
# Data for MPWR
# 10
# Data for MQ
# Data for MRAM
# Data for MRIN
# -4
# Data for MRVL
# 10
# Data for MSCI
# 10
# Data for MSFT
# 10
# Data for MSI
# 10
# Data for MSP
# Data for MSTR
# -10
# Data for MTC
# Data for MTLS
# Data for MTSI
# -10
# Data for MTTR
# Data for MTTRW
# Data for MU
# 10
# Data for MX
# Data for MXL
# -10
# Data for MYPS
# Data for MYPSW
# Data for MYSZ
# Data for NABL
# Data for NATI
# 10
# Data for NCMI
# -8
# Data for NCNO
# Data for NCTY
# Data for NET
# Data for NEWR
# Data for NICE
# Data for NLOK
# Data for NNDM
# Data for NOK
# Data for NOW
# 10
# Data for NPTN
# 6
# Data for NRDS
# Data for NRDY
# Data for NSIT
# -10
# Data for NSP
# -6
# Data for NTAP
# 10
# Data for NTCT
# -10
# Data for NTNX
# Data for NTWK
# Data for NUAN
# 4
# Data for NVDA
# 10
# Data for NVEC
# -10
# Data for NVTS
# Data for NVTSW
# Data for NXPI
# Data for NXTP
# Data for OBLG
# Data for OCFT
# Data for OIIM
# Data for OKTA
# Data for OLB
# Data for OLED
# -10
# Data for OLO
# Data for OMC
# -2
# Data for OMQS
# Data for ON
# Data for ONEM
# Data for ONTF
# Data for ONTO
# Data for OPFI
# Data for OPRA
# Data for ORCL
# 10
# Data for OSPN
# Data for OSS
# Data for OTRK
# Data for OTRKP
# Data for PAGS
# Data for PALT
# Data for PANW
# 10
# Data for PAR
# Data for PATH
# Data for PAY
# -8
# Data for PAYA
# Data for PAYC
# 10
# Data for PAYO
# Data for PAYOW
# Data for PAYS
# Data for PBTS
# Data for PCOR
# Data for PCTI
# 0
# Data for PCTY
# 10
# Data for PCYG
# -4
# Data for PD
# Data for PDFS
# -10
# Data for PEAR
# Data for PEARW
# Data for PEGA
# 10
# Data for PERI
# -10
# Data for PFDRU
# Data for PFDRW
# Data for PHUN
# Data for PHUNW
# Data for PING
# Data for PIXY
# Data for PLAB
# -4
# Data for PLAN
# Data for PLTK
# Data for PLTR
# Data for PLUS
# -4
# Data for PLXS
# 10
# Data for POWI
# -8
# Data for PRAA
# 10
# Data for PRCH
# Data for PRFT
# 10
# Data for PRG
# Data for PRGS
# -2
# Data for PRO
# 10
# Data for PRTH
# Data for PRVA
# Data for PSTG
# Data for PT
# Data for PTC
# Data for PUBM
# Data for PWSC
# Data for PXLW
# Data for PYCR
# Data for QCOM
# 0
# Data for QD
# Data for QLYS
# 10
# Data for QMCO
# Data for QNST
# 10
# Data for QTT
# Data for QTWO
# 10
# Data for QUBT
# Data for QUIK
# -4
# Data for QUMU
# Data for QUOT
# Data for RAAS
# Data for RAMP
# Data for RBBN
# Data for RBCN
# -10
# Data for RBLX
# Data for RCAT
# Data for RCII
# -10
# Data for RDCM
# Data for RDVT
# Data for RDWR
# Data for REKR
# Data for RELL
# 8
# Data for RELY
# Data for RENN
# Data for RESN
# Data for RHI
# 10
# Data for RIOT
# Data for RMBS
# -2
# Data for RMNI
# Data for RNG
# 10
# Data for RNWK
# -6
# Data for ROL
# 10
# Data for RPAY
# Data for RPD
# Data for RSSS
# Data for RXT
# Data for S
# -10
# Data for SABR
# Data for SABRP
# Data for SAIC
# 10
# Data for SAIL
# Data for SANM
# -8
# Data for SAP
# Data for SATS
# -10
# Data for SCKT
# Data for SCPL
# Data for SCSC
# -8
# Data for SCWX
# Data for SDGR
# Data for SE
# -10
# Data for SEAC
# -2
# Data for SEDG
# Data for SEMR
# Data for SFET
# Data for SFUN
# Data for SGFY
# Data for SGH
# Data for SGLB
# Data for SGLBW
# Data for SGMA
# Data for SHCR
# Data for SHCRW
# Data for SHLS
# Data for SILC
# Data for SIMO
# Data for SITM
# Data for SJ
# Data for SKLZ
# Data for SKYT
# Data for SLAB
# 10
# Data for SLF
# Data for SLP
# Data for SMAR
# Data for SMCI
# -10
# Data for SMFR
# Data for SMFRW
# Data for SMRT
# -4
# Data for SMSI
# Data for SMTC
# 4
# Data for SNAP
# Data for SNCE
# Data for SNCR
# 0
# Data for SNOW
# 8
# Data for SNPS
# 0
# Data for SNX
# -8
# Data for SOHU
# Data for SOL
# Data for SOPA
# Data for SPCB
# Data for SPGI
# 10
# Data for SPI
# Data for SPLK
# 10
# Data for SPNS
# -10
# Data for SPOK
# Data for SPSC
# 10
# Data for SPT
# Data for SPWR
# -8
# Data for SQ
# Data for SQNS
# Data for SQSP
# Data for SRAX
# Data for SREV
# 10
# Data for SSNC
# 10
# Data for SSNT
# Data for SSTI
# Data for SSYS
# -2
# Data for STAF
# Data for STEM
# Data for STER
# Data for STGW
# Data for STM
# Data for STNE
# Data for STRM
# Data for STRN
# Data for STRNW
# Data for STX
# 10
# Data for SUMO
# Data for SUNW
# Data for SURG
# Data for SURGW
# Data for SWCH
# Data for SWI
# 10
# Data for SWKS
# 10
# Data for SY
# Data for SYNA
# 10
# Data for TACT
# Data for TAIT
# Data for TAOP
# Data for TASK
# Data for TBI
# 2
# Data for TCX
# Data for TDC
# -4
# Data for TEAM
# Data for TEL
# 10
# Data for TENB
# Data for TGH
# -8
# Data for TLS
# Data for TNET
# 10
# Data for TOST
# Data for TPIC
# Data for TRIT
# Data for TRITW
# Data for TRKA
# Data for TRKAW
# Data for TRNS
# Data for TRS
# -2
# Data for TRT
# Data for TRTN
# Data for TRU
# Data for TRVG
# Data for TSEM
# Data for TSM
# Data for TSQ
# Data for TSRI
# Data for TTD
# Data for TTEC
# -10
# Data for TTMI
# 10
# Data for TTWO
# -2
# Data for TUFN
# Data for TUYA
# Data for TWKS
# Data for TWTR
# 10
# Data for TXN
# 8
# Data for TYL
# 10
# Data for TZOO
# 0
# Data for U
# Data for UBER
# Data for UCTT
# -8
# Data for UEPS
# Data for UI
# Data for UIS
# 10
# Data for ULBI
# Data for UMC
# Data for UPH
# Data for UPLD
# Data for URI
# 10
# Data for USER
# Data for USIO
# Data for UTRS
# Data for VALU
# Data for VCSA
# Data for VECO
# 4
# Data for VENAR
# Data for VERB
# Data for VERBW
# Data for VERI
# Data for VERX
# Data for VIAO
# Data for VIAV
# Data for VMEO
# Data for VMW
# 4
# Data for VNET
# Data for VOLT
# Data for VRAR
# Data for VRNS
# 10
# Data for VRNT
# -10
# Data for VRSN
# 10
# Data for VSAT
# 4
# Data for WAVD
# Data for WB
# Data for WDAY
# 10
# Data for WDC
# 10
# Data for WEAV
# Data for WEX
# 10
# Data for WFCF
# Data for WIMI
# Data for WISA
# Data for WIT
# Data for WIX
# 10
# Data for WK
# Data for WKEY
# Data for WOLF
# Data for WPP
# -10
# Data for WSC
# Data for WSTG
# Data for WTRH
# Data for WYY
# Data for XELA
# Data for XLNX
# 10
# Data for XM
# Data for XMTR
# Data for XNET
# Data for XPER
# Data for XRX
# -4
# Data for YALA
# Data for YELP
# 10
# Data for YEXT
# Data for YNDX
# Data for YOU
# Data for YY
# Data for ZBRA
# 10
# Data for ZD
# Data for ZDGE
# Data for ZEN
# 10
# Data for ZEPP
# Data for ZETA
# Data for ZI
# Data for ZIP
# Data for ZM
# Data for ZNGA
# -8
# Data for ZS
# Data for ZUO

# %%
techlist2
# Out:
# ['AAPL',
#  'ACN',
#  'ADI',
#  'AMSWA',
#  'AVT',
#  'BBSI',
#  'BLKB',
#  'CCMP',
#  'CMTL',
#  'CSCO',
#  'CSGS',
#  'CTSH',
#  'DLB',
#  'DLX',
#  'DOX',
#  'DV',
#  'DXC',
#  'EBIX',
#  'EFX',
#  'ENTG',
#  'EVER',
#  'EVTC',
#  'FSS',
#  'HCKT',
#  'HEES',
#  'HPQ',
#  'HSII',
#  'IBM',
#  'INTC',
#  'INTU',
#  'IPG',
#  'JBL',
#  'JKHY',
#  'KAI',
#  'KELYA',
#  'KFRC',
#  'KFY',
#  'LDOS',
#  'LFUS',
#  'LRCX',
#  'MANT',
#  'MCHP',
#  'MCO',
#  'MGRC',
#  'MORN',
#  'MPWR',
#  'MRVL',
#  'MSCI',
#  'MSFT',
#  'MSI',
#  'NATI',
#  'NTAP',
#  'NVDA',
#  'ORCL',
#  'PEGA',
#  'RELL',
#  'RHI',
#  'ROL',
#  'SAIC',
#  'SPGI',
#  'SSNC',
#  'STX',
#  'SWKS',
#  'TEL',
#  'TXN',
#  'WDC',
#  'XLNX']

# %%
# Check for dividend and plot the whole data for verification
for i in techlist2:
    df = getdf(wikitech,i)
    for j in df['ex-dividend']:
        if j !=0:
            print(f'expected dividend of {i} is {j}')
    fig = go.Figure()
    fig.add_trace(go.Scatter(x=df.index,y=df['close'], name = 'close'))
    fig.add_trace(go.Scatter(x=df.index,y = df['adj_close'], name = 'adjusted close'))
    fig.update_layout(title = i, template = 'plotly_dark')
    fig.show()
# Out:
# "for i in techlist2:\n    df = getdf(wikitech,i)\n    for j in df['ex-dividend']:\n        if j !=0:\n            print(f'expected dividend of {i} is {j}')\n    fig = go.Figure()\n    fig.add_trace(go.Scatter(x=df.index,y=df['close'], name = 'close'))\n    fig.add_trace(go.Scatter(x=df.index,y = df['adj_close'], name = 'adjusted close'))\n    fig.update_layout(title = i, template = 'plotly_dark')\n    fig.show()"

# %%
techlist3 = []
for i in tech:
    df = getdf(wikitech,i)
    if df['volume'].any()!=0:
        mean, momentum1 = rollingmean(df, 1, 90)
        print(sum(momentum1))
        if sum(momentum1) > 0 and sum(mean['ex-dividend']) > 0:
            techlist3.append(i)
    else:
        pass
# Out:
# Data for AAOI
# -82
# Data for AAPL
# -88
# Data for ABM
# -88
# Data for ACEV
# Data for ACEVU
# Data for ACEVW
# Data for ACIW
# -48
# Data for ACLS
# -88
# Data for ACMR
# Data for ACN
# -88
# Data for ACVA
# Data for ACY
# Data for ADBE
# 6
# Data for ADI
# -14
# Data for ADSK
# 24
# Data for ADTH
# Data for ADV
# Data for ADVWW
# Data for AER
# Data for AEYE
# Data for AFRM
# Data for AGIL
# Data for AGILW
# Data for AGMH
# Data for AGYS
# 4
# Data for AI
# 88
# Data for AIP
# Data for AIRG
# Data for AL
# -88
# Data for ALF
# Data for ALFIW
# Data for ALGM
# Data for ALIT
# Data for ALKT
# Data for ALOT
# Data for ALRM
# Data for ALTG
# Data for ALTR
# 88
# Data for AMBA
# -88
# Data for AMD
# -88
# Data for AMKR
# -88
# Data for AMPL
# Data for AMST
# Data for AMSWA
# -88
# Data for AMWL
# Data for ANET
# Data for ANGI
# -88
# Data for ANSS
# -88
# Data for ANTE
# Data for AOSL
# -88
# Data for API
# Data for APP
# -88
# Data for APPF
# Data for APPN
# Data for APPS
# Data for ARNC
# -86
# Data for ARRY
# -88
# Data for ARW
# -86
# Data for ASAN
# Data for ASGN
# 6
# Data for ASML
# Data for ASUR
# Data for ASX
# Data for ASYS
# Data for ATEN
# -88
# Data for ATHM
# Data for ATKR
# Data for ATOM
# Data for ATVI
# -88
# Data for AUGX
# Data for AUID
# Data for AUR
# Data for AUROW
# Data for AUUD
# Data for AUUDW
# Data for AVCT
# Data for AVCTW
# Data for AVDX
# Data for AVGO
# -88
# Data for AVGOP
# Data for AVID
# -74
# Data for AVLR
# Data for AVPT
# Data for AVPTW
# Data for AVT
# -88
# Data for AVYA
# Data for AWRE
# Data for AXTI
# Data for AYX
# Data for AZPN
# 6
# Data for AZTA
# Data for BAND
# Data for BASE
# Data for BBAI
# Data for BBSI
# 32
# Data for BCOV
# -30
# Data for BDR
# Data for BEAT
# -88
# Data for BEATW
# Data for BEEM
# Data for BEEMW
# Data for BGSF
# Data for BHE
# -88
# Data for BIDU
# -88
# Data for BIGC
# Data for BILI
# Data for BILL
# Data for BKI
# Data for BKKT
# Data for BKTI
# Data for BL
# Data for BLBX
# Data for BLCT
# Data for BLIN
# Data for BLKB
# -36
# Data for BLND
# Data for BLZE
# Data for BMBL
# Data for BMTX
# Data for BNFT
# 48
# Data for BOMN
# Data for BOSC
# Data for BOX
# Data for BRDS
# Data for BRZE
# Data for BSQR
# Data for BSY
# Data for BTCM
# Data for BTRS
# Data for BTRSW
# Data for BW
# Data for CACI
# -16
# Data for CALX
# -6
# Data for CAN
# Data for CANG
# Data for CASA
# Data for CCCS
# Data for CCMP
# -4
# Data for CCO
# 56
# Data for CCRN
# -88
# Data for CCSI
# Data for CDAY
# Data for CDK
# Data for CDLX
# Data for CDNS
# -88
# Data for CDW
# Data for CETX
# Data for CETXP
# Data for CETXW
# Data for CEVA
# -88
# Data for CFLT
# Data for CGNT
# Data for CHKP
# -88
# Data for CIH
# Data for CLIR
# Data for CLPS
# Data for CLRO
# Data for CLSK
# Data for CMAX
# Data for CMAXW
# Data for CMBM
# Data for CMCM
# Data for CMTL
# 46
# Data for CNDT
# Data for CNET
# Data for CNVY
# Data for CNXC
# Data for CNXN
# Data for COIN
# Data for COMM
# Data for COMP
# Data for COUP
# 8
# Data for CPSI
# -88
# Data for CREX
# Data for CREXW
# Data for CRM
# -88
# Data for CRNC
# Data for CRNT
# Data for CRSR
# Data for CRTO
# Data for CRUS
# -88
# Data for CRWD
# Data for CSCO
# -66
# Data for CSGS
# -86
# Data for CSPI
# Data for CTEK
# Data for CTG
# 48
# Data for CTK
# Data for CTLP
# Data for CTOS
# Data for CTSH
# -50
# Data for CTV
# Data for CTXS
# -4
# Data for CUEN
# Data for CUENW
# Data for CVLT
# 54
# Data for CVT
# 80
# Data for CVV
# Data for CWAN
# Data for CXM
# Data for CYBR
# Data for CYN
# 72
# Data for CYRN
# Data for CYXT
# Data for CYXTW
# Data for DATS
# Data for DATSW
# Data for DAVA
# Data for DBD
# -86
# Data for DBX
# Data for DCT
# -62
# Data for DDD
# 24
# Data for DDI
# Data for DDOG
# Data for DELL
# -88
# Data for DGII
# 76
# Data for DH
# Data for DHX
# 2
# Data for DIOD
# -6
# Data for DLB
# -88
# Data for DLX
# -28
# Data for DM
# Data for DMRC
# -88
# Data for DMS
# Data for DNB
# 80
# Data for DOCN
# Data for DOCS
# Data for DOCU
# Data for DOMO
# Data for DOX
# -88
# Data for DOYU
# Data for DQ
# Data for DSP
# Data for DT
# Data for DTSS
# Data for DTST
# Data for DTSTW
# Data for DUO
# Data for DUOL
# Data for DUOT
# Data for DV
# -14
# Data for DXC
# -8
# Data for EA
# -88
# Data for EB
# Data for EBIX
# -88
# Data for EBON
# Data for ECOM
# Data for EEFT
# -88
# Data for EEX
# Data for EFX
# -88
# Data for EGAN
# 82
# Data for EGHT
# -8
# Data for ELTK
# Data for EMBK
# Data for EMBKW
# Data for EMKR
# Data for ENFN
# Data for ENTG
# 22
# Data for ENV
# 38
# Data for EOSE
# Data for EOSEW
# Data for EPAM
# -88
# Data for EPAY
# -30
# Data for ERIC
# Data for ERII
# 50
# Data for ESMT
# Data for ESSC
# Data for ESTC
# Data for ETWO
# Data for EVBG
# Data for EVCM
# Data for EVER
# 88
# Data for EVOL
# Data for EVOP
# Data for EVTC
# -30
# Data for EXFY
# Data for EXLS
# -88
# Data for EXTN
# Data for EZFL
# Data for FB
# -88
# Data for FDS
# -88
# Data for FFIV
# -38
# Data for FICO
# -88
# Data for FISV
# -88
# Data for FIVN
# 8
# Data for FLEX
# Data for FLT
# -88
# Data for FLYW
# Data for FORA
# Data for FORG
# Data for FORM
# -74
# Data for FORTY
# Data for FOUR
# Data for FROG
# Data for FRSH
# 54
# Data for FRSX
# Data for FSLR
# 88
# Data for FSLY
# Data for FSS
# 20
# Data for FTAI
# Data for FTCI
# Data for FTFT
# Data for GAN
# Data for GB
# -56
# Data for GBOX
# Data for GDDY
# Data for GDOT
# 4
# Data for GDRX
# Data for GDS
# Data for GDYN
# Data for GIC
# Data for GIGM
# Data for GILT
# Data for GLBE
# Data for GLG
# Data for GOOG
# -88
# Data for GOOGL
# -88
# Data for GRPN
# -86
# Data for GSIT
# -88
# Data for GSKY
# Data for GSMG
# Data for GSMGW
# Data for GTEC
# Data for GTLB
# Data for GTLS
# 24
# Data for GTYH
# Data for GVP
# Data for GWRE
# -88
# Data for HAYW
# Data for HCKT
# -88
# Data for HCP
# 26
# Data for HCTI
# Data for HEES
# -88
# Data for HHR
# Data for HHS
# 60
# Data for HIMX
# Data for HLIT
# 72
# Data for HLTH
# Data for HOOD
# Data for HPQ
# -88
# Data for HQI
# Data for HRI
# Data for HSII
# 52
# Data for HSON
# Data for HUBS
# Data for IAS
# Data for IBEX
# Data for IBM
# -84
# Data for ICHR
# Data for ICLK
# Data for IDEX
# Data for IDN
# Data for IGC
# Data for III
# -74
# Data for IIIV
# Data for IMMR
# 10
# Data for IMOS
# Data for IMXI
# Data for INDI
# Data for INDIW
# Data for INFA
# 88
# Data for INFO
# 88
# Data for INFY
# Data for INOD
# Data for INPX
# Data for INS
# Data for INST
# Data for INSW
# Data for INTA
# Data for INTC
# 66
# Data for INTT
# Data for INTU
# 20
# Data for INUV
# Data for INVE
# Data for IOT
# Data for IPDN
# Data for IPG
# -40
# Data for IPGP
# -88
# Data for IQ
# Data for IRNT
# Data for ISDR
# Data for ISIG
# Data for ISUN
# Data for ITRN
# Data for IZEA
# Data for JAMF
# Data for JBL
# 38
# Data for JG
# Data for JKHY
# -88
# Data for JKS
# Data for JNPR
# -88
# Data for JOB
# Data for JOBS
# Data for JT
# Data for KAI
# -88
# Data for KARO
# Data for KBNT
# Data for KBNTW
# Data for KC
# Data for KD
# Data for KELYA
# -88
# Data for KELYB
# Data for KFRC
# -80
# Data for KFY
# 88
# Data for KLIC
# Data for KLR
# Data for KLTR
# Data for KNBE
# Data for KPLT
# Data for KPLTW
# Data for KTCC
# Data for KVHI
# -88
# Data for LASR
# Data for LAW
# Data for LAZR
# Data for LDOS
# -88
# Data for LEDS
# Data for LFUS
# -88
# Data for LITE
# Data for LIZI
# Data for LOGI
# Data for LPSN
# 82
# Data for LRCX
# -2
# Data for LSCC
# -88
# Data for LTCH
# Data for LTCHW
# Data for LVOX
# Data for LVOXW
# Data for LYFT
# Data for LYLT
# Data for LZ
# Data for MAN
# -86
# Data for MANH
# -88
# Data for MANT
# -10
# Data for MAPS
# Data for MAPSW
# Data for MCFE
# Data for MCHP
# 24
# Data for MCO
# -88
# Data for MDB
# Data for MDRX
# -88
# Data for MFC
# Data for MFGP
# Data for MFH
# Data for MGIC
# Data for MGNI
# Data for MGRC
# 48
# Data for MICT
# Data for MIGI
# Data for MIME
# Data for MIR
# Data for MITK
# -88
# Data for MIXT
# Data for MKFG
# Data for MKTW
# Data for MKTWW
# Data for ML
# Data for MMAT
# Data for MNDO
# Data for MNDT
# Data for MNTV
# Data for MOBQ
# Data for MOBQW
# Data for MODN
# 4
# Data for MOMO
# Data for MORN
# -56
# Data for MPWR
# -88
# Data for MQ
# Data for MRAM
# Data for MRIN
# -88
# Data for MRVL
# -88
# Data for MSCI
# 46
# Data for MSFT
# -88
# Data for MSI
# -8
# Data for MSP
# Data for MSTR
# -88
# Data for MTC
# Data for MTLS
# Data for MTSI
# -88
# Data for MTTR
# Data for MTTRW
# Data for MU
# 6
# Data for MX
# Data for MXL
# -88
# Data for MYPS
# Data for MYPSW
# Data for MYSZ
# Data for NABL
# Data for NATI
# -48
# Data for NCMI
# -88
# Data for NCNO
# Data for NCTY
# Data for NET
# Data for NEWR
# Data for NICE
# Data for NLOK
# Data for NNDM
# Data for NOK
# Data for NOW
# -8
# Data for NPTN
# -86
# Data for NRDS
# Data for NRDY
# Data for NSIT
# -84
# Data for NSP
# 20
# Data for NTAP
# -46
# Data for NTCT
# -88
# Data for NTNX
# Data for NTWK
# Data for NUAN
# -88
# Data for NVDA
# -88
# Data for NVEC
# 4
# Data for NVTS
# Data for NVTSW
# Data for NXPI
# Data for NXTP
# Data for OBLG
# Data for OCFT
# Data for OIIM
# Data for OKTA
# Data for OLB
# Data for OLED
# -88
# Data for OLO
# Data for OMC
# -60
# Data for OMQS
# Data for ON
# Data for ONEM
# Data for ONTF
# Data for ONTO
# Data for OPFI
# Data for OPRA
# Data for ORCL
# -88
# Data for OSPN
# Data for OSS
# Data for OTRK
# Data for OTRKP
# Data for PAGS
# Data for PALT
# Data for PANW
# 10
# Data for PAR
# Data for PATH
# Data for PAY
# -88
# Data for PAYA
# Data for PAYC
# 34
# Data for PAYO
# Data for PAYOW
# Data for PAYS
# Data for PBTS
# Data for PCOR
# Data for PCTI
# -10
# Data for PCTY
# 32
# Data for PCYG
# -88
# Data for PD
# Data for PDFS
# -88
# Data for PEAR
# Data for PEARW
# Data for PEGA
# 36
# Data for PERI
# -82
# Data for PFDRU
# Data for PFDRW
# Data for PHUN
# Data for PHUNW
# Data for PING
# Data for PIXY
# Data for PLAB
# -88
# Data for PLAN
# Data for PLTK
# Data for PLTR
# Data for PLUS
# -68
# Data for PLXS
# -88
# Data for POWI
# -80
# Data for PRAA
# -22
# Data for PRCH
# Data for PRFT
# 26
# Data for PRG
# Data for PRGS
# -88
# Data for PRO
# 48
# Data for PRTH
# Data for PRVA
# Data for PSTG
# Data for PT
# Data for PTC
# Data for PUBM
# Data for PWSC
# Data for PXLW
# Data for PYCR
# Data for QCOM
# -88
# Data for QD
# Data for QLYS
# -8
# Data for QMCO
# Data for QNST
# 48
# Data for QTT
# Data for QTWO
# 26
# Data for QUBT
# Data for QUIK
# -88
# Data for QUMU
# Data for QUOT
# Data for RAAS
# Data for RAMP
# Data for RBBN
# Data for RBCN
# -82
# Data for RBLX
# Data for RCAT
# Data for RCII
# 2
# Data for RDCM
# Data for RDVT
# Data for RDWR
# Data for REKR
# Data for RELL
# -88
# Data for RELY
# Data for RENN
# Data for RESN
# Data for RHI
# -86
# Data for RIOT
# Data for RMBS
# 48
# Data for RMNI
# Data for RNG
# 10
# Data for RNWK
# 42
# Data for ROL
# -4
# Data for RPAY
# Data for RPD
# Data for RSSS
# Data for RXT
# Data for S
# -88
# Data for SABR
# Data for SABRP
# Data for SAIC
# -88
# Data for SAIL
# Data for SANM
# -88
# Data for SAP
# Data for SATS
# -88
# Data for SCKT
# Data for SCPL
# Data for SCSC
# 88
# Data for SCWX
# Data for SDGR
# Data for SE
# 88
# Data for SEAC
# -88
# Data for SEDG
# Data for SEMR
# Data for SFET
# Data for SFUN
# Data for SGFY
# Data for SGH
# Data for SGLB
# Data for SGLBW
# Data for SGMA
# Data for SHCR
# Data for SHCRW
# Data for SHLS
# Data for SILC
# Data for SIMO
# Data for SITM
# Data for SJ
# Data for SKLZ
# Data for SKYT
# Data for SLAB
# -88
# Data for SLF
# Data for SLP
# Data for SMAR
# Data for SMCI
# -88
# Data for SMFR
# Data for SMFRW
# Data for SMRT
# 64
# Data for SMSI
# Data for SMTC
# 62
# Data for SNAP
# Data for SNCE
# Data for SNCR
# 82
# Data for SNOW
# 84
# Data for SNPS
# -88
# Data for SNX
# -88
# Data for SOHU
# Data for SOL
# Data for SOPA
# Data for SPCB
# Data for SPGI
# -20
# Data for SPI
# Data for SPLK
# -4
# Data for SPNS
# -86
# Data for SPOK
# Data for SPSC
# 22
# Data for SPT
# Data for SPWR
# 68
# Data for SQ
# Data for SQNS
# Data for SQSP
# Data for SRAX
# Data for SREV
# -32
# Data for SSNC
# 48
# Data for SSNT
# Data for SSTI
# Data for SSYS
# -88
# Data for STAF
# Data for STEM
# Data for STER
# Data for STGW
# Data for STM
# Data for STNE
# Data for STRM
# Data for STRN
# Data for STRNW
# Data for STX
# 28
# Data for SUMO
# Data for SUNW
# Data for SURG
# Data for SURGW
# Data for SWCH
# Data for SWI
# 84
# Data for SWKS
# -88
# Data for SY
# Data for SYNA
# -76
# Data for TACT
# Data for TAIT
# Data for TAOP
# Data for TASK
# Data for TBI
# -88
# Data for TCX
# Data for TDC
# 80
# Data for TEAM
# Data for TEL
# -88
# Data for TENB
# Data for TGH
# -88
# Data for TLS
# Data for TNET
# 22
# Data for TOST
# Data for TPIC
# Data for TRIT
# Data for TRITW
# Data for TRKA
# Data for TRKAW
# Data for TRNS
# Data for TRS
# -58
# Data for TRT
# Data for TRTN
# Data for TRU
# Data for TRVG
# Data for TSEM
# Data for TSM
# Data for TSQ
# Data for TSRI
# Data for TTD
# Data for TTEC
# -80
# Data for TTMI
# -88
# Data for TTWO
# -88
# Data for TUFN
# Data for TUYA
# Data for TWKS
# Data for TWTR
# -88
# Data for TXN
# -88
# Data for TYL
# 36
# Data for TZOO
# 88
# Data for U
# Data for UBER
# Data for UCTT
# -88
# Data for UEPS
# Data for UI
# Data for UIS
# -36
# Data for ULBI
# Data for UMC
# Data for UPH
# Data for UPLD
# Data for URI
# -76
# Data for USER
# Data for USIO
# Data for UTRS
# Data for VALU
# Data for VCSA
# Data for VECO
# -88
# Data for VENAR
# Data for VERB
# Data for VERBW
# Data for VERI
# Data for VERX
# Data for VIAO
# Data for VIAV
# Data for VMEO
# Data for VMW
# -60
# Data for VNET
# Data for VOLT
# Data for VRAR
# Data for VRNS
# 40
# Data for VRNT
# -88
# Data for VRSN
# -10
# Data for VSAT
# -88
# Data for WAVD
# Data for WB
# Data for WDAY
# -32
# Data for WDC
# -6
# Data for WEAV
# Data for WEX
# -2
# Data for WFCF
# Data for WIMI
# Data for WISA
# Data for WIT
# Data for WIX
# -4
# Data for WK
# Data for WKEY
# Data for WOLF
# Data for WPP
# -80
# Data for WSC
# Data for WSTG
# Data for WTRH
# Data for WYY
# Data for XELA
# Data for XLNX
# -18
# Data for XM
# Data for XMTR
# Data for XNET
# Data for XPER
# Data for XRX
# -88
# Data for YALA
# Data for YELP
# -88
# Data for YEXT
# Data for YNDX
# Data for YOU
# Data for YY
# Data for ZBRA
# -2
# Data for ZD
# Data for ZDGE
# Data for ZEN
# 54
# Data for ZEPP
# Data for ZETA
# Data for ZI
# Data for ZIP
# Data for ZM
# Data for ZNGA
# 32
# Data for ZS
# Data for ZUO

# %%
techlist3
# Out:
# ['CYN', 'EVER']

# %%
# Check for dividend and plot the whole data for verification
for i in techlist3:
    df = getdf(wikitech,i)
    for j in df['ex-dividend']:
        if j !=0:
            print(f'expected dividend of {i} is {j}')
    fig = go.Figure()
    fig.add_trace(go.Scatter(x=df.index,y=df['close'], name = 'close'))
    fig.add_trace(go.Scatter(x=df.index,y = df['adj_close'], name = 'adjusted close'))
    fig.update_layout(title = i, template = 'plotly_dark')
    fig.show()
# Out:
# "for i in techlist3:\n    df = getdf(wikitech,i)\n    for j in df['ex-dividend']:\n        if j !=0:\n            print(f'expected dividend of {i} is {j}')\n    fig = go.Figure()\n    fig.add_trace(go.Scatter(x=df.index,y=df['close'], name = 'close'))\n    fig.add_trace(go.Scatter(x=df.index,y = df['adj_close'], name = 'adjusted close'))\n    fig.update_layout(title = i, template = 'plotly_dark')\n    fig.show()"
